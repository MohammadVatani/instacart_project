# %% [markdown]
# # import modules

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %matplotlib inline

os.chdir('C:\\Users\\Admin\\DM_project') #I use this line to change my current work directory

# %% [markdown]
# # Hide warnings
# I use this script to hide warnings accur during run code.

# %%
# %%javascript
# (function(on) {
# const e=$( "<a>Setup failed</a>" );
# const ns="js_jupyter_suppress_warnings";
# var cssrules=$("#"+ns);
# if(!cssrules.length) cssrules = $("<style id='"+ns+"' type='text/css'>div.output_stderr { } </style>").appendTo("head");
# e.click(function() {
#     var s='Showing';
#     cssrules.empty()
#     if(on) {
#         s='Hiding';
#         cssrules.append("div.output_stderr, div[data-mime-type*='.stderr'] { display:none; }");
#     }
#     e.text(s+' warnings (click to toggle)');
#     on=!on;
# }).click();
# $(element).append(e);
# })(true);

# %% [markdown]
# ## Read csv files

# %%
orders_df = pd.read_csv('.//input//orders.csv')
aisles_df = pd.read_csv('.//input//aisles.csv') 
department_df = pd.read_csv('.//input//departments.csv')
order_products__prior_df = pd.read_csv('./input//order_products__prior.csv')
order_products__train_df = pd.read_csv('.//input//order_products__train.csv')
products_df = pd.read_csv('.//input//products.csv')

# %% [markdown]
# To gain more information about dataset, I use leftjoin between order_products__prior_df and products_df on product_id.

# %%
order_products__prior_df = pd.merge(order_products__prior_df, products_df, on='product_id', how='left')

# %%
order_products__prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id
# 0        86             16
# 1        83              4
# 2       104             13
# 3        19             13
# 4        17             13

# %% [markdown]
# Here we have the name of products on each order!

# %%
products = order_products__prior_df['product_name'].value_counts().reset_index()
products.columns = ['product_name', 'frequency_count']
products.head(10)
# Out:
#              product_name  frequency_count
# 0                  Banana           472565
# 1  Bag of Organic Bananas           379450
# 2    Organic Strawberries           264683
# 3    Organic Baby Spinach           241921
# 4    Organic Hass Avocado           213584
# 5         Organic Avocado           176815
# 6             Large Lemon           152657
# 7            Strawberries           142951
# 8                   Limes           140627
# 9      Organic Whole Milk           137905

# %% [markdown]
# by using groupby method, now we have Number of products sold.
# ## merge order_products__prior_df with aisles_df

# %%
order_products__prior_df = pd.merge(order_products__prior_df, aisles_df, on='aisle_id', how='left')

# %%
order_products__prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id               aisle
# 0        86             16                eggs
# 1        83              4    fresh vegetables
# 2       104             13   spices seasonings
# 3        19             13       oils vinegars
# 4        17             13  baking ingredients

# %% [markdown]
# so here we have aisles on our dataset.

# %%
aisles = order_products__prior_df['aisle'].value_counts().head(40)
plt.figure(figsize=(16,8))
sns.barplot(aisles.index, aisles.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Aisle', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# D:\soft\jupiter\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
aisles = order_products__prior_df['aisle'].value_counts().reset_index().head(15)
aisles.columns = ['aisle', 'frequency_count']
label = np.array(aisles.aisle)
aisles.plot.pie(labels=label,y='frequency_count',figsize=(10, 10))
# Out:
# <AxesSubplot:ylabel='frequency_count'>

# %% [markdown]
# ## merge order_products__prior_df and department_df

# %%
order_products__prior_df = pd.merge(order_products__prior_df, department_df, on='department_id', how='left')

# %%
order_products__prior_df.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered           product_name  \
# 0         2       33120                  1          1     Organic Egg Whites
# 1         2       28985                  2          1  Michigan Organic Kale
# 2         2        9327                  3          0          Garlic Powder
# 3         2       45918                  4          1         Coconut Butter
# 4         2       30035                  5          0      Natural Sweetener
#
#    aisle_id  department_id               aisle  department
# 0        86             16                eggs  dairy eggs
# 1        83              4    fresh vegetables     produce
# 2       104             13   spices seasonings      pantry
# 3        19             13       oils vinegars      pantry
# 4        17             13  baking ingredients      pantry

# %%
departments = order_products__prior_df['department'].value_counts()
plt.figure(figsize=(16,8))
sns.barplot(departments.index, departments.values, alpha=0.8)
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('department', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# D:\soft\jupiter\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# above you can see which department have more occurrences.

# %%
department_reoder = order_products__prior_df.groupby('department')['reordered'].aggregate('mean').reset_index()

plt.figure(figsize=(16,8))
sns.barplot(department_reoder['department'].values, department_reoder['reordered'].values, alpha=0.8)
plt.ylabel('rate of reorder', fontsize=12)
plt.xlabel('department', fontsize=12)
plt.xticks(rotation='vertical')
plt.show()
# Out:
# D:\soft\jupiter\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# dairy eggs - beverage - backery have highest rate of reorder as expected!
#
# ## merge order_products__train_df and orders_df
# in this part, I intend to draw a few plots Using the merged data.

# %%
order_products__train_df = pd.merge(order_products__train_df, orders_df, on='order_id', how='left')

# %%
order_products__train_df.head(10)
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id eval_set  \
# 0         1       49302                  1          1   112108    train
# 1         1       11109                  2          1   112108    train
# 2         1       10246                  3          0   112108    train
# 3         1       49683                  4          0   112108    train
# 4         1       43633                  5          1   112108    train
# 5         1       13176                  6          0   112108    train
# 6         1       47209                  7          0   112108    train
# 7         1       22035                  8          1   112108    train
# 8        36       39612                  1          0    79431    train
# 9        36       19660                  2          1    79431    train
#
#    order_number  order_dow  order_hour_of_day  days_since_prior_order
# 0             4          4                 10                     9.0
# 1             4          4                 10                     9.0
# 2             4          4                 10                     9.0
# 3             4          4                 10                     9.0
# 4             4          4                 10                     9.0
# 5             4          4                 10                     9.0
# 6             4          4                 10                     9.0
# 7             4          4                 10                     9.0
# 8            23          6                 18                    30.0
# 9            23          6                 18                    30.0

# %%
purchase_order_dow = order_products__train_df.groupby('order_dow')['add_to_cart_order'].aggregate('mean').reset_index()
purchase_order_dow.head(10)
# Out:
#    order_dow  add_to_cart_order
# 0          0           9.233182
# 1          1           8.743371
# 2          2           8.490926
# 3          3           8.405128
# 4          4           8.408802
# 5          5           8.566949
# 6          6           8.924705

# %%
label = np.array(purchase_order_dow.order_dow)
purchase_order_dow.plot.pie(labels=label,y='add_to_cart_order',figsize=(10, 10))
plt.show()

# %% [markdown]
# as we can see, The average number of products add to cart is almost equal every day.

# %%
order_dow_reordered = order_products__train_df.groupby("order_dow")["reordered"].aggregate("mean").reset_index()

plt.figure(figsize=(12,8))
sns.barplot(order_dow_reordered['order_dow'].values, order_dow_reordered['reordered'].values, alpha=0.8)
plt.ylabel('Reorder ratio', fontsize=12)
plt.xlabel('Day of week', fontsize=12)
plt.title("Reorder ratio across day of week", fontsize=15)
plt.xticks(rotation='vertical')
plt.ylim(0.4, 0.7)
plt.show()
# Out:
# D:\soft\jupiter\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# It seems there is no assosiation between reorder ratio and day of the week
